# %%
subjects =[]
for i in range(6):
    subject = input(f"Enter a subject {i+1}: ")
    topic =input(f'Enter the topic for {subject}: ')
    subjects.append((subject, topic))
print(subjects)

subs = [('history', 'battle of hastings'), ('geog', 'global migration'), ('maths', 'trig'), ('chem', 'bonds'), ('phy', 'moments'), ('comp', 'programming')]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 subjects =[]
#       2 for i in range(6):
# ----> 3     subject = input(f"Enter a subject {i+1}: ")
#       4     topic =input(f'Enter the topic for {subject}: ')
#       5     subjects.append((subject, topic))
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %%
subs = [('history', 'battle of hastings'), ('geog', 'global migration'), ('maths', 'trig'), ('chem', 'bonds'), ('phy', 'moments'), ('comp', 'programming')]
for i in range(len(subs)):
    print(f'{subs[i][0]}\t{subs[i][1]}')
tofind = input("Enter a subject to find: ")
for i in range(len(subs)):
    if subs[i][0].lower() ==tofind.lower():
        print("Found")
# Out:
# history	battle of hastings
# geog	global migration
# maths	trig
# chem	bonds
# phy	moments
# comp	programming
