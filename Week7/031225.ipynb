# %%
def volumeCube():
    while True:
        try:
            length = int(input('length: '))
            width = int(input(' width: '))
            height = int(input('height: '))

            volume = length*width*height
            print(f'Volume is {volume} cubic units')
            break
        except ValueError:
            print('only numbers may be entered')

volumeCube()
# Out:
# Volume is 216 cubic units

# %%
def main():
    menu = """
1. Volume of a cube
2. Quadratic formula
3. Percentage Change
4. Can Vote
5. quit"""
    while True:
        print(menu)
        while True:
            try:
                menuChoice = int(input('Enter a menu choice: '))
            except: 
                print("Please enter a number from the menu: ")
        if menuchoice == 5:
            break
        elif menuChoice ==1:
            volumeCube()

# %%
def percentagechange():
    while True:
        try:
            num1 = int(input("Enter your change in number: "))
            num2 = int(input("Enter your original number: "))
        
        percentagechange = num1/num2 * 100
        print(f'Your percentage change is {percentagechange}')
