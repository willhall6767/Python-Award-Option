# %%
num1 = float(input('Enter you original value of QD'))
num2 = float(input('Enter your new value of QD'))
num3 = float(input('Enter you original price'))
num4 = float(input('Enter your new price'))

difference = num2-num1

changeinQD = ((num2-num1)/num1)*100
print(f"Your change in QD is {changeinQD}")

changeinprice = ((num4-num3)/num3)*100
print(f"Your change in price is {changeinprice}")


PED = changeinQD/changeinprice
print(f"Your price elasticity of demand is {PED}")
# Out:
# Your change in QD is 50.0
# Your change in price is 20.0
# Your price elasticity of demand is 2.5

# %%
num1 = float(input('Enter your inital QD of first good'))
num2 = float(input('Enter you price of your second good'))

crosselasticityofdemand = num1/num2
print(f"Your XED is {crosselasticityofdemand}")
# Out:
# Your XED is 0.06666666666666667
